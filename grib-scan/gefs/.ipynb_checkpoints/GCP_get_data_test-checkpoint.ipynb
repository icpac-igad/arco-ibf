# %%
## list of all variables needed in training cGAN


var_names = {\
    'Convective available potential energy',
    'Convective precipitation (water)',
    'Medium cloud cover',
    'Surface pressure',
    'Upward short-wave radiation flux',
    'Downward short-wave radiation flux',
    '2 metre temperature',
    'Cloud water',
    'Precipitable water',
    'Ice water mixing ratio',
    'Cloud mixing ratio',
    'Rain mixing ratio',
    'Total Precipitation'
    'U component of wind',
    'V component of wind'
}
    


var_levels = {\
    'surface',
    'surface',
    'middleCloudLayer',
    'surface',
    'surface',
    'surface',
    'heightAboveGround',
    'atmosphereSingleLayer',
    'atmosphereSingleLayer',
    'isobaricInhPa',
    'isobaricInhPa',
    'isobaricInhPa',
    'surface',
    'isobaricInhPa',
    'isobaricInhPa',
}

# %%
import utils
import importlib
importlib.reload(utils)
import numpy as np

time_beg = '2021-02-18'
time_end = '2021-02-19'

for date in np.arange(time_beg, time_end, np.timedelta64(1,'D'), dtype='datetime64'):

    year = str(date).split('-')[0]
    month = str(date).split('-')[1]
    date = str(date).replace('-','')

    for run in ['06']:
        gcp_urls = utils.gefs_gcp_utl_maker(date,run, ensemble_members = np.arange(3,4))
        filenames = utils.gen_json_gcp(gcp_urls, ['Convective available potential energy'], ['surface'])

# %%
importlib.reload(utils)
utils.gefs_gcp_utl_maker('20210218','06', ensemble_members = np.arange(5))
# Out:
# ['gs://global-forecast-system/gfs.20210218/06/gfs.t06z.pgrb2.0p25.f000',
#  'gs://global-forecast-system/gfs.20210218/06/gfs.t06z.pgrb2.0p25.f003']

# %%
import fsspec
fsspec.filesystem("gcs", anon=True).glob(f"gs://global-forecast-system/gfs.20230301/00/atmos/gfs.t00z.pgrb2.0p25.f004*")
# Out:
# ['global-forecast-system/gfs.20230301/00/atmos/gfs.t00z.pgrb2.0p25.f004',
#  'global-forecast-system/gfs.20230301/00/atmos/gfs.t00z.pgrb2.0p25.f004.idx']

# %%
from google.cloud import storage
from cfgrib.xarray_store import open_dataset

import google.auth

#credentials, project = google.auth.default()


client = storage.Client.create_anonymous_client()
bucket = client.bucket('global-forecast-system', user_project=None)
#blob = bucket.blob('gfs.20230301/00/atmos/gfs.20230301/00/atmos/gfs.t00z.pgrb2.0p25.f003')

blob = storage.Blob('gfs.20230301/00/atmos/gfs.t00z.pgrb2.0p25.f003', bucket)

#blob.download_to_filename(filename='gfs.t00z.pgrb2.0p25.f003', client=client)

with blob.open('rb') as f:

    open_dataset(f.read(), 
                 filter_by_keys={\
                     'typeOfLevel': 'surface', 
                    'name':'Surface pressure'
                 })

# %%
 df = open_dataset('gfs.t00z.pgrb2.0p25.f003', 
                 filter_by_keys={\
                     'typeOfLevel': 'surface', 
                    'name':'Surface pressure'
                 })

# %%
df
# Out:
# <xarray.Dataset> Size: 4MB
# Dimensions:     (latitude: 721, longitude: 1440)
# Coordinates:
#     time        datetime64[ns] 8B ...
#     step        timedelta64[ns] 8B ...
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     valid_time  datetime64[ns] 8B ...
# Data variables:
#     sp          (latitude, longitude) float32 4MB 1.006e+05 ... 6.855e+04
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2024-03-13T16:38 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

fig1=plt.figure(figsize=(8,5))
plt.rcParams.update({'font.size': 10})
plt.rcParams.update({'mathtext.default':'regular'}) 
plt.rcParams.update({'mathtext.default':'it'}) 


ax=fig1.add_subplot(1,1,1,projection=ccrs.Robinson(central_longitude=0))
ax.coastlines()

mesh_1=ax.pcolormesh(
    df.longitude.values, df.latitude.values, df.sp.values,  cmap='coolwarm', transform=ccrs.PlateCarree(), 
    rasterized=True
                    )

#ax.set_title(model+" "+scen+" "+time_sel,y=1.02,fontsize=12)# 

plt.colorbar(mesh_1, orientation='horizontal', shrink=0.6)
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /home/n/nath/nobackup/anaconda3/envs/kerchunk_2024/share/proj failed
# /home/n/nath/nobackup/anaconda3/envs/kerchunk_2024/lib/python3.10/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/110m_physical/ne_110m_coastline.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
